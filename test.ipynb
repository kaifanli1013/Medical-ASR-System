# %%
res = [Segment(id=1, seek=730, start=np.float64(0.7199999999999998), end=np.float64(7.28), text='疾病の診断ってどうやるんですか具体的に 通常の診断は普通にその症状が同齢', tokens=[50364, 18140, 122, 30986, 2972, 5396, 118, 4307, 255, 6102, 18395, 7355, 4895, 27113, 3703, 39806, 29485, 1546, 4108, 220, 19550, 11279, 2972, 5396, 118, 4307, 255, 3065, 29993, 19550, 4108, 20564, 15553, 229, 35276, 114, 5142, 13089, 44628, 95, 50822], temperature=0.0, avg_logprob=-0.3887676958526884, compression_ratio=1.0495049504950495, no_speech_prob=0.45474767684936523, words=[Word(start=np.float64(0.7199999999999998), end=np.float64(1.08), word='疾', probability=np.float64(0.47006630524992943)), Word(start=np.float64(1.08), end=np.float64(1.18), word='病', probability=np.float64(0.8998967409133911)), Word(start=np.float64(1.18), end=np.float64(1.4), word='の', probability=np.float64(0.8900384306907654)), Word(start=np.float64(1.4), end=np.float64(1.86), word='診', probability=np.float64(0.9898810386657715)), Word(start=np.float64(1.86), end=np.float64(2.06), word='断', probability=np.float64(0.9989592432975769)), Word(start=np.float64(2.06), end=np.float64(2.14), word='って', probability=np.float64(0.2912808656692505)), Word(start=np.float64(2.14), end=np.float64(2.32), word='どう', probability=np.float64(0.955069899559021)), Word(start=np.float64(2.32), end=np.float64(2.44), word='や', probability=np.float64(0.9571936726570129)), Word(start=np.float64(2.44), end=np.float64(2.5), word='る', probability=np.float64(0.9935257434844971)), Word(start=np.float64(2.5), end=np.float64(2.68), word='んです', probability=np.float64(0.9382832646369934)), Word(start=np.float64(2.68), end=np.float64(2.88), word='か', probability=np.float64(0.9972032308578491)), Word(start=np.float64(2.88), end=np.float64(3.12), word='具', probability=np.float64(0.5266343355178833)), Word(start=np.float64(3.12), end=np.float64(3.22), word='体', probability=np.float64(0.9987649917602539)), Word(start=np.float64(3.22), end=np.float64(3.4), word='的', probability=np.float64(0.9874477982521057)), Word(start=np.float64(3.4), end=np.float64(3.62), word='に', probability=np.float64(0.9133260250091553)), Word(start=np.float64(3.68), end=np.float64(3.82), word=' 通', probability=np.float64(0.15033185482025146)), Word(start=np.float64(3.82), end=np.float64(4.0), word='常', probability=np.float64(0.8723625540733337)), Word(start=np.float64(4.0), end=np.float64(4.12), word='の', probability=np.float64(0.9758687615394592)), Word(start=np.float64(4.12), end=np.float64(4.36), word='診', probability=np.float64(0.9853990375995636)), Word(start=np.float64(4.36), end=np.float64(4.6), word='断', probability=np.float64(0.9991427063941956)), Word(start=np.float64(4.6), end=np.float64(4.96), word='は', probability=np.float64(0.9601312279701233)), Word(start=np.float64(4.96), end=np.float64(5.32), word='普', probability=np.float64(0.4025832712650299)), Word(start=np.float64(5.32), end=np.float64(5.88), word='通', probability=np.float64(0.9994674324989319)), Word(start=np.float64(5.88), end=np.float64(6.06), word='に', probability=np.float64(0.9610229730606079)), Word(start=np.float64(6.06), end=np.float64(6.32), word='その', probability=np.float64(0.7973378896713257)), Word(start=np.float64(6.32), end=np.float64(6.62), word='症', probability=np.float64(0.9752481877803802)), Word(start=np.float64(6.62), end=np.float64(6.8), word='状', probability=np.float64(0.9872588813304901)), Word(start=np.float64(6.8), end=np.float64(6.96), word='が', probability=np.float64(0.9484860897064209)), Word(start=np.float64(6.96), end=np.float64(7.16), word='同', probability=np.float64(0.2829590141773224)), Word(start=np.float64(7.16), end=np.float64(7.28), word='齢', probability=np.float64(0.752752959728241))])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ...

# %%
from faster_whisper import WhisperModel

model = WhisperModel("large-v3")

segments, info = model.transcribe("audio.mp3")
for segment in segments:
    print("[%.2fs -> %.2fs] %s" % (segment.start, segment.end, segment.text))
# Out:
# Hello World
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 5
#       3 print("Hello World")
#       4 audio = './test.wav'
# ----> 5 model = whisper.load_model("large-v2") #or large-v3
#       7 result = model.transcribe(
#       8 audio=audio,
#       9 language='en',
#      10 word_timestamps=True,
#      11 task="transcribe"
#      12 )
#      14 print(result["text"])
#
# AttributeError: module 'whisper' has no attribute 'load_model'
